# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import numpy as np

# %%
data = pd.read_csv("Data/industries.csv")

# %%
data
# Out:
#      code                                        description
# 0      11                     Growing of non-perennial crops
# 1     111  Growing of cereals (except rice), leguminous c...
# 2     112                                    Growing of rice
# 3     113  Growing of vegetables and melons, roots and tu...
# 4     114                              Growing of sugar cane
# ..    ...                                                ...
# 882  9810  Undifferentiated goods-producing activities of...
# 883   982  Undifferentiated service-producing activities ...
# 884  9820  Undifferentiated service-producing activities ...
# 885   990  Activities of extraterritorial organisations a...
# 886  9900  Activities of extraterritorial organisations a...
#
# [887 rows x 2 columns]

# %%
comdata = pd.read_json("Data/merger_data.json")

# %%
comdata
# Out:
#        date_completion                      bidders_name  \
# 0                 None                                []
# 1                 None           [cmc centrozlom sp zoo]
# 2                 None            [morningstar japan kk]
# 3           2023-04-03   [fabryka obrabiarek rafamet sa]
# 4           2014-04-22        [fabrika kartona umka doo]
# ...                ...                               ...
# 825768      2004-07-14  [taj gvk hotels and resorts ltd]
# 825769            None                                []
# 825770            None            [mitutoyo corporation]
# 825771            None           [woori technology inc.]
# 825772            None                                []
#
#        date_completion_assumed date_last_status_update             status  \
# 0                         None                    None   Rumour - Expired
# 1                         None                    None   Rumour - Expired
# ...

# %%
comdata.describe()
# Out:
#                  id
# count  8.257730e+05
# mean   1.308088e+09
# std    8.362040e+08
# min    3.085700e+04
# 25%    5.684240e+05
# 50%    1.633051e+09
# 75%    1.941122e+09
# max    2.007601e+09

# %%
comdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825773 entries, 0 to 825772
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   date_completion           506135 non-null  object
#  1   bidders_name              825773 non-null  object
#  2   date_completion_assumed   161144 non-null  object
#  3   date_last_status_update   175350 non-null  object
#  4   status                    825773 non-null  object
#  5   bidders_industry          825773 non-null  object
#  6   id                        825773 non-null  int64
#  7   comments                  825773 non-null  object
#  8   targets_industry          825773 non-null  object
#  9   targets_isin              825773 non-null  object
#  10  date_rumor                825773 non-null  object
#  11  date_postponed            214 non-null     object
#  12  date_announcement         696242 non-null  object
# ...
